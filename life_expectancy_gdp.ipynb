# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("all_data.csv")
print(df.head())
df["GDP"] = df["GDP"].apply(lambda x : x / 1000000000)
df.rename(columns = {"GDP" : "GDP ($Billion)"}, inplace = True)
print(df.head())
df["Country"].unique()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10
#   Country  Year  Life expectancy at birth (years)  GDP ($Billion)
# 0   Chile  2000                              77.3       77.860932
# 1   Chile  2001                              77.3       70.979924
# 2   Chile  2002                              77.8       69.736811
# 3   Chile  2003                              77.9       75.643460
# 4   Chile  2004                              78.0       99.210393
# array(['Chile', 'China', 'Germany', 'Mexico', 'United States of America',
#        'Zimbabwe'], dtype=object)

# %%
top3_df = df[(df.Country == "China") | (df.Country == "Germany") | (df.Country == "United States of America")]
bottom3_df = df[(df.Country == "Chile") | (df.Country == "Mexico") | (df.Country == "Zimbabwe")]
sns.barplot(data = top3_df, x = "Year", y = "GDP ($Billion)", hue = "Country")
plt.show()
plt.clf()
sns.barplot(data = bottom3_df, x = "Year", y = "GDP ($Billion)", hue = "Country")
plt.show()
plt.clf()

# %%
def plt_gdp_LE(df, country):
    plt.plot(df["GDP ($Billion)"][df.Country == country], df["Life expectancy at birth (years)"][df.Country == country])
    plt.xlabel("GDP ($Billion)")
    
plt.subplot(1, 3, 1)
plt_gdp_LE(top3_df, 'United States of America')
plt.ylabel("Life expectancy at birth (years)")
plt.subplot(1, 3, 2)
plt_gdp_LE(top3_df, 'China')
plt.title("GDP x Life Expectancy of Highest 3 Countries By GDP")
plt.subplot(1, 3, 3)
plt_gdp_LE(top3_df, 'Germany')



plt.show()
plt.clf()

# %%
plt.subplot(1, 3, 1)
plt_gdp_LE(bottom3_df, 'Mexico')
plt.ylabel("Life expectancy at birth (years)")
plt.subplot(1, 3, 2)
plt_gdp_LE(bottom3_df, 'Chile')
plt.title("GDP x Life Expectancy of Highest 3 Countries By GDP")
plt.subplot(1, 3, 3)
plt_gdp_LE(bottom3_df, 'Zimbabwe')



plt.show()
plt.clf()
